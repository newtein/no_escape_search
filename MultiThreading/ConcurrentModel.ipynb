# %%
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
#["Q500.txt","Q1000.txt","Q2000.txt","Q4000.txt","Q8000.txt"]
files=["Q500.txt","Q1000.txt","Q2000.txt","Q4000.txt","Q8000.txt"]
plt.close()

for val in files:
    f=open(val,"r")
    x,y=[],[]
    for thread,l in zip(range(10,800,10),f):
        x.append(int(thread))
        y.append(float(l.strip()))
        
    plt.subplots(figsize=(7,3),dpi=300)    
    val=val.split(".txt")[0][1 :]    
    plt.plot(x,y,label=val,color='b')
    
    fit=np.polyfit(x,y,3)
    y_new=np.polyval(fit,x)
    
    fit2=np.polyfit(x,y,2)
    y_new2=np.polyval(fit2,x)
    
    plt.plot(x,y_new,label=val,color='g')
    plt.plot(x,y_new2,label=val,color='c')
    plt.scatter(x,y,s=20,color='b')
    plt.xlabel("No of Threads")
    plt.ylabel("Time(in secs)")
    plt.legend(loc="upper right")
    plt.title("No Of Queries:"+val)
    plt.show()
    f.close()
    print(np.poly1d(fit))
# Out:
#             3             2
# -6.986e-08 x + 0.0001217 x - 0.06882 x + 12.82
#             3            2
# -5.601e-08 x + 9.71e-05 x - 0.0686 x + 20.18
#             3            2
# -4.852e-08 x + 0.000106 x - 0.08328 x + 23.32
#             3             2
# -1.684e-08 x + 5.054e-05 x - 0.05579 x + 20.35
#            3             2
# 6.629e-09 x + 2.254e-05 x - 0.04801 x + 20.42

# %%
mintime=2
# -5.601e-08 x + 9.71e-05 x - 0.0686 x + 20.18
for x in range(10,800,10):
    #=3.789e-05 *pow(x,2) - 0.04182*pow(x,1)  + 10.96
    #y=-6.986e-08 *pow(x,3) + 0.0001217 *pow(x,2) - 0.06882 *pow(x,1) + 12.82
    y=-5.601e-08 *pow(x,3) + 9.71e-05 *pow(x,2) - 0.0686 *pow(x,1) + 20.18
    if y<mintime:
        print(x,y)
        break
# Out:
# 600 1.8778400000000062

# %%
for x in range(10,800,10):
    #=3.789e-05 *pow(x,2) - 0.04182*pow(x,1)  + 10.96
    y=-6.986e-08 *pow(x,3) + 0.0001217 *pow(x,2) - 0.06882 *pow(x,1) + 12.82
    qfactor=0.0025*1000+2.075
    fx=y-qfactor
    #print(fx)
    if fx==0 or (-0.1<fx<0.1):
        print(x,y,fx)
        #break
# Out:
# 160 4.638173439999999 0.06317343999999903

# %%
pow(2,2)
# Out:
# 4

# %%
from sympy import S, symbols
import sympy
from matplotlib import pyplot as plt
import numpy as np

x=np.linspace(0,1,100)
y=np.sin(2 * np.pi * x)

p = np.polyfit(x, y, 5)
f = np.poly1d(p)
print(f)

# calculate new x's and y's
x_new = np.linspace(x[0], x[-1], 50)
y_new = f(x_new)

x = symbols("x")
poly = sum(S("{:6.2f}".format(v))*x**i for i, v in enumerate(p[::-1]))
eq_latex = sympy.printing.latex(poly)

plt.plot(x_new, y_new, label="${}$".format(eq_latex))
plt.legend(fontsize="small")
plt.show()
# Out:
#         5         4         3         2
# -54.84 x + 137.1 x - 98.69 x + 10.93 x + 5.473 x + 0.01287

# %%
files=["I500 .txt","I1000 .txt"]
plt.close()
for val in files:
    f=open(val,"r")
    x,y=[],[]
    for thread,l in zip(range(10,800,10),f):
        x.append(int(thread))
        y.append(float(l.strip()))
    plt.subplots(figsize=(7,3),dpi=300)    
    val=val.split(".txt")[0][1 :]    
    plt.plot(x,y,label=val,color='b')
    plt.scatter(x,y,s=20,color='b')
    plt.xlabel("No of Threads")
    plt.ylabel("Time(in secs)")
    plt.legend(loc="upper right")
    plt.title("No Of Queries:"+val)
    plt.show()
    f.close()

# %%
files=["I500.txt","I1000.txt","I2000.txt","I4000.txt","I8000.txt"]
plt.close()
plt.subplots(figsize=(7,3),dpi=300)
for val in files:
    f=open(val,"r")
    x,y=[],[]
    for thread,l in zip(range(10,800,10),f):
        x.append(int(thread))
        y.append(float(l.strip()))    
    val=val.split(".txt")[0][1 :]    
    plt.plot(x,y,label=val)
    #plt.scatter(x,y,s=20,color='b')
    f.close()
plt.xlabel("No of Threads")
plt.ylabel("Time(in secs)")
plt.legend(loc="upper right")
plt.title("Insertion Time")
plt.show()

# %%
files=["I2000 .txt","I4000 .txt","I8000 .txt"]
plt.close()
for val in files:
    f=open(val,"r")
    x,y=[],[]
    for thread,l in zip(range(10,800,50),f):
        x.append(int(thread))
        y.append(float(l.strip()))
    plt.subplots(figsize=(7,3),dpi=300)    
    val=val.split(".txt")[0][1 :]    
    plt.plot(x,y,label=val,color='b')
    plt.scatter(x,y,s=20,color='b')
    plt.xlabel("No of Threads")
    plt.ylabel("Time(in secs)")
    plt.legend(loc="upper right")
    plt.title("No Of Queries:"+val)
    plt.show()
    f.close()

# %%
x=[500,1000,2000,4000]
y=[240,280,310,360]
a=linregress(x,y)
print(a)
# Out:
# LinregressResult(slope=0.03182608695652174, intercept=237.82608695652175, rvalue=0.97394174700251568, pvalue=0.026058252997484314, stderr=0.0052405284081110904)

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.       ,  0.9359882],
#        [ 0.9359882,  1.       ]])

# %%
plt.plot(x,y)
plt.show()

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit([x],y)
print('Coefficients: \n', regr.coef_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-9f362049611b> in <module>()
#       4
#       5 # Train the model using the training sets
# ----> 6 regr.fit([x],y)
#       7 print('Coefficients: \n', regr.coef_)
#
# c:\program files (x86)\python36-32\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# c:\program files (x86)\python36-32\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     581         y = y.astype(np.float64)
#     582
# --> 583     check_consistent_length(X, y)
#     584
#     585     return X, y
#
# c:\program files (x86)\python36-32\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [1, 4]

# %%
files=["I1000.txt"]
plt.close()
for val in files:
    f=open(val,"r")
    x,y=[],[]
    for thread,l in zip(range(10,800,20),f):
        x.append(int(thread))
        y.append(float(l.strip()))
    plt.subplots(figsize=(7,3),dpi=300)    
    val=val.split(".txt")[0][1 :]    
    plt.plot(x,y,label=val,color='b')
    plt.scatter(x,y,s=20,color='b')
    plt.xlabel("No of Threads")
    plt.ylabel("Time(in secs)")
    plt.legend(loc="upper right")
    plt.title("No Of Queries:"+val)
    plt.show()
    f.close()

# %%
#["Q500.txt","Q1000.txt","Q2000.txt","Q4000.txt","Q8000.txt"]
import os
XX,YY,ZZ=[],[],[]
p,q,r=[],[],[]
A,B,C,D,Q=[],[],[],[],[]
#files=["Q500.txt","Q1000.txt","Q2000.txt"]
#files=["Q500.txt","Q1000.txt","Q2000.txt","Q4000.txt","Q8000.txt"]
plt.close()
sns.set()
for val in files:
    f=open("Arc/"+val,"r")
    x,y=[],[]
    for thread,l in zip(range(10,800,10),f):
        x.append(int(thread))
        y.append(float(l.strip(",")[0].strip()))
        
    plt.subplots(figsize=(5,3),dpi=300)    
    val=val.split(".txt")[0][1 :]    
    plt.plot(x,y,label=val,color='b')
    
    fit=np.polyfit(x,y,3)
    y_new=np.polyval(fit,x)
    
    fit2=np.polyfit(x,y,2)
    y_new2=np.polyval(fit2,x)
    for ii,jj in zip(x,y):
        XX.append(ii)
        YY.append(jj)
        ZZ.append(int(val))
        
    for ii,jj in zip(y,y_new):
        p.append(ii)
        q.append(jj)
        r.append(int(val))
        
    plt.plot(x,y_new,label=val,color='g')
    plt.plot(x,y_new2,label=val,color='c')
    plt.scatter(x,y,s=20,color='b')
    plt.xlabel("No of Threads")
    plt.ylabel("Time(in secs)")
    plt.legend(loc="upper right")
    plt.title("No Of Queries:"+val)
    plt.show()
    f.close()
    #print()
    f=np.poly1d(fit)
    print(f,f.coef,1.28206907e+01)
    yy=f.coef
    A.append(yy[0])
    B.append(yy[1])
    C.append(yy[2])
    D.append(yy[3])
    Q.append(int(val))
# Out:
#            3             2
# 1.333e-08 x + 1.042e-06 x - 0.0153 x + 5.52 [  1.33273473e-08   1.04242183e-06  -1.53039432e-02   5.51980465e+00] 12.8206907
#            3             2
# 8.119e-08 x - 0.0001099 x + 0.03348 x + 2.52 [  8.11866763e-08  -1.09905084e-04   3.34772667e-02   2.52039300e+00] 12.8206907
#            3             2
# 1.109e-07 x - 0.0001419 x + 0.0439 x + 0.9503 [  1.10900476e-07  -1.41884932e-04   4.39029378e-02   9.50267932e-01] 12.8206907
#            3             2
# 6.911e-08 x - 9.379e-05 x + 0.02818 x + 2.559 [  6.91098035e-08  -9.37905726e-05   2.81821356e-02   2.55881227e+00] 12.8206907
#            3             2
# 1.486e-08 x - 2.037e-05 x + 0.002316 x + 3.437 [  1.48578678e-08  -2.03661685e-05   2.31554969e-03   3.43742400e+00] 12.8206907

# %%
# -6.986e-08 x + 0.0001217 x - 0.06882 x + 12.82
xx=486.75
# y
-6.986e-08*pow(xx,3)+0.0001217*pow(xx,2)- 0.06882*xx+12.82

#2*0.0001217
## y''
#6*-6.986e-08 *xx+2*0.0001217
5e2
# Out:
# 500.0

# %%
import sys

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import numpy
from numpy.random import randn
from scipy import array, newaxis
sns.reset_defaults()
DATA=[]
for i,j,k in zip(XX,YY,ZZ):
    DATA.append([i,j,k])
DATA=np.array(DATA)
Xs = DATA[:,0]
Ys = DATA[:,1]
Zs = DATA[:,2]


# ======
## plot:

fig = plt.figure(dpi=300)

ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_trisurf(Xs, Ys, Zs, cmap=cm.jet, linewidth=0)
fig.colorbar(surf)

ax.xaxis.set_major_locator(MaxNLocator(5))
ax.yaxis.set_major_locator(MaxNLocator(6))
ax.zaxis.set_major_locator(MaxNLocator(5))
ax.set_xlabel("Thread Count")
ax.set_ylabel("Insertion Time (in sec)")
ax.set_zlabel("Queries")
fig.tight_layout()

plt.show()

# %%
from scipy.stats import linregress
tdata=[]
y=linregress(Q,A)
tdata.append((y.slope,y.intercept))
y=linregress(Q,B)
tdata.append((y.slope,y.intercept))
y=linregress(Q,C)
tdata.append((y.slope,y.intercept))
y=linregress(Q,D)
tdata.append((y.slope,y.intercept))

print(tdata)
var=[]
for i in tdata:
    var.append(i[0]*1000+i[1])
print(var)    

mintime=0.2
for x in range(10,800,10):
    #=3.789e-05 *pow(x,2) - 0.04182*pow(x,1)  + 10.96
    y=-5.7803728069279393e-08 *pow(x,3) + 0.00010673087790926715 *pow(x,2) -0.072188237623407481 *pow(x,1) + 18.458033398648148
    if y<mintime:
        print(x,y)
        break
        
#-5.601e-08 x + 9.71e-05 x - 0.0686 x + 20.18
# Out:
# [(-5.1648191268090849e-12, 7.3887373457718825e-08), (5.3752167758031802e-09, -8.9644039082297034e-05), (-1.1315893459562495e-06, 0.022022716280585899), (-4.1486651754780945e-05, 3.1259489906665934)]
# [6.8722554330909736e-08, -8.4268822306493853e-05, 0.020891126934629651, 3.0844623389118127]
# 730 0.1508718890822962

# %%
import numpy as np
import statsmodels.api as sm

def reg_m(y, x):
    ones = np.ones(len(x[0]))
    X = sm.add_constant(np.column_stack((x[0], ones)))
    for ele in x[1:]:
        X = sm.add_constant(np.column_stack((ele, X)))
    results = sm.OLS(y, X).fit()
    return results

print (reg_m(p, [q,r]).summary())
# Out:
# c:\program files (x86)\python36-32\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.608
# Model:                            OLS   Adj. R-squared:                  0.604
# Method:                 Least Squares   F-statistic:                     178.8
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.22e-47
# Time:                        00:53:01   Log-Likelihood:                -681.90
# No. Observations:                 234   AIC:                             1370.
# Df Residuals:                     231   BIC:                             1380.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          2.739e-17      0.000   5.55e-14      1.000      -0.001       0.001
# x2             1.0000      0.055     18.128      0.000       0.891       1.109
# const      -3.998e-15      0.631  -6.34e-15      1.000      -1.243       1.243
# ==============================================================================
# Omnibus:                      190.955   Durbin-Watson:                   1.357
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3831.322
# Skew:                           3.016   Prob(JB):                         0.00
# Kurtosis:                      21.883   Cond. No.                     2.82e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.82e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit ([[i,j] for i,j in zip(q,r)], p)
print(reg.coef_)
reg.intercept_
# Out:
# [  1.00000000e+00   5.46729554e-18]
# 8.8817841970012523e-16

# %%
reg.fit ([[i,j] for i,j in zip(q,r)], p)
print(reg.coef_)
reg.intercept_
# Out:
# LinregressResult(slope=0.0025456981651638209, intercept=2.0752895100788411, rvalue=0.28460419969178469, pvalue=9.7752796437199748e-06, stderr=0.00056296251038511001)
# [  1.00000000e+00   5.46729554e-18]
# 8.8817841970012523e-16

# %%
from scipy.optimize import curve_fit
import scipy

def fn(x, a, b, c):
    return a + b*x[0] + c*x[1]

# y(x0,x1) data:
#    x0=0 1 2
# ___________
# x1=0 |0 1 2
# x1=1 |1 2 3
# x1=2 |2 3 4

x = scipy.array([q,r])
y = scipy.array(p)
popt, pcov = curve_fit(fn, x, y)
print (popt,pcov)
# Out:
# [  3.86419160e-08   9.99999981e-01   4.52208271e-11] [[  2.47610861e-02  -2.21691457e-03  -1.35200938e-05]
#  [ -2.21691457e-03   2.91594811e-03  -6.52980420e-06]
#  [ -1.35200938e-05  -6.52980420e-06   5.81986986e-08]]

# %%
for i,j,k in zip(q,r,p):
    print(i,j,"-->",k)
# Out:
# 12.1445944481 500 --> 23.472280263900757
# 11.4924230333 500 --> 13.854527473449707
# 10.8637572648 500 --> 8.662935495376587
# 10.2581779774 500 --> 6.402513265609741
# 9.67526600614 500 --> 6.867888927459717
# 9.11460218575 500 --> 5.906640529632568
# 8.57576735113 500 --> 6.918304204940796
# 8.05834233715 500 --> 3.763901948928833
# 7.56190797868 500 --> 3.0088987350463867
# 7.08604511057 500 --> 3.7396867275238037
# 6.6303345677 500 --> 3.4532997608184814
# 6.19435718492 500 --> 3.463693857192993
# 5.77769379711 500 --> 3.629728317260742
# 5.37992523913 500 --> 8.213529586791992
# 5.00063234584 500 --> 7.848429203033447
# 4.6393959521 500 --> 10.387491941452026
# 4.29579689279 500 --> 9.429679155349731
# 3.96941600277 500 --> 11.767719745635986
# 3.6598341169 500 --> 6.091169834136963
# 3.36663207004 500 --> 2.6719374656677246
# 3.08939069707 500 --> 2.683119297027588
# 2.82769083285 500 --> 5.147320508956909
# 2.58111331224 500 --> 6.020395517349243
# 2.3492389701 500 --> 3.6172828674316406
# 2.13164864131 500 --> 0.09402608871459961
# 1.92792316072 500 --> 0.10318827629089355
# 1.73764336321 500 --> 0.08418726921081543
# 1.56039008363 500 --> 0.09967827796936035
# 1.39574415685 500 --> 0.11120176315307617
# 1.24328641774 500 --> 0.10202598571777344
# 1.10259770116 500 --> 0.10977840423583984
# 0.973258841978 500 --> 0.10017085075378418
# 0.854850675055 500 --> 0.15729951858520508
# 0.746954035258 500 --> 0.0987701416015625
# 0.649149757452 500 --> 0.13836956024169922
# 0.561018676501 500 --> 0.1159355640411377
# 0.482141627271 500 --> 0.14037537574768066
# 0.412099444626 500 --> 0.1038672924041748
# 0.350472963431 500 --> 0.12332367897033691
# 0.296843018552 500 --> 0.13866853713989258
# 0.250790444852 500 --> 0.12706875801086426
# 0.211896077198 500 --> 0.15423250198364258
# 0.179740750453 500 --> 0.18329739570617676
# 0.153905299483 500 --> 0.15524983406066895
# 0.133970559153 500 --> 0.13226795196533203
